# %% [markdown]
# # 🌾 India Districts Crop Production — Full ML Pipeline
#
# **Dataset:** India Districts Crop Production (27,303 rows × 21 columns)
# **Target:** `Production` — crop output in thousand tonnes across Indian districts
# **Years covered:** 2021-22, 2022-23, 2023-24
# **Crops:** 19 types including Rice, Wheat, Maize, Bajra, Pulses, etc.
#
# **Pipeline:**
# 1. Load & EDA
# 2. Handle zeros & log-transform skewed features
# 3. Feature engineering & preprocessing (no leakage)
# 4. Baseline models (Linear Regression, Decision Tree, Random Forest, SVR)
# 5. Hyperparameter tuning (GridSearchCV / RandomizedSearchCV)
# 6. XGBoost & LightGBM
# 7. Learning curves
# 8. Residual analysis
# 9. SHAP (global + local XAI)
# 10. LIME (local XAI)
# 11. Final comparison table — all metrics

# %% [markdown]
# ---
# ## 1. Imports & Package Setup
#
# We import all required libraries upfront and auto-install any ML/XAI packages that may not already be present in the environment.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import subprocess, sys
for pkg in ['xgboost', 'lightgbm', 'shap', 'lime']:
    subprocess.run([sys.executable, '-m', 'pip', 'install', pkg, '-q'], check=False)

print('✅ All packages ready.')

# %% [markdown]
# ---
# ## 2. Load & Explore the Data
#
# ### About this dataset
# Each row represents a **crop grown in a specific district in a specific year**. Features include:
# - **Geographic:** State, District, Latitude, Longitude
# - **Agronomic:** Crop type, Year
# - **Soil:** Nitrogen, Phosphorus, Potassium (NPK), Organic Carbon, Soil pH
# - **Weather:** Temperature, Humidity, Precipitation, Sunshine hours
# - **Pre-encoded:** State_Encoded, District_Encoded, Crop_Encoded (label-encoded versions of categoricals)
# - **Target:** `Production` (in thousand tonnes)
#
# Note: `Country` is always 'India' — we drop it. `Ind_adm2_ID` is just a geographic ID — not a useful predictor.

# %%
df = pd.read_csv('India_Districts_Crop_Production_Processed.csv')

print('Shape:', df.shape)
print('\nColumns:', list(df.columns))
df.head()

# %%
# Statistical summary — check min/max/mean for anomalies
# Key things to notice:
# - Production min = 0, 25th percentile = 0 → more than half the rows are zero production!
# - Production max = 3090 but mean = 90 → extreme right skew
df.describe()

# %%
print('Missing values:')
print(df.isnull().sum())
print('\n✅ No missing values in this dataset — no imputation needed.')

# %%
# Dataset composition
print('Unique States :', df['State'].nunique())
print('Unique Districts:', df['District'].nunique())
print('Unique Crops  :', df['Crop'].nunique(), '→', list(df['Crop'].unique()))
print('Years covered :', list(df['Year'].unique()))

print(f'\nZero-production rows: {(df["Production"]==0).sum()} out of {len(df)} ({(df["Production"]==0).mean()*100:.1f}%)')
print('This means many districts did not grow a particular crop in a given year.')

# %% [markdown]
# ### Visualising the Data

# %%
# Top 10 crops by total production
top_crops = df.groupby('Crop')['Production'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 5))
top_crops.plot(kind='bar', color='steelblue', edgecolor='white')
plt.title('Top 10 Crops by Total Production (All Years)')
plt.ylabel('Total Production (thousand tonnes)')
plt.xlabel('Crop')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Top 10 states by production
top_states = df.groupby('State')['Production'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 5))
top_states.plot(kind='bar', color='tomato', edgecolor='white')
plt.title('Top 10 States by Total Production')
plt.ylabel('Total Production (thousand tonnes)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Year-over-year production trend
yearly = df.groupby('Year')['Production'].sum()
plt.figure(figsize=(7, 4))
yearly.plot(kind='bar', color=['#5cb85c', '#337ab7', '#f0ad4e'], edgecolor='white')
plt.title('Total Production by Year')
plt.ylabel('Total Production (thousand tonnes)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Correlation heatmap — numeric features only
# Drop identifier columns before computing correlations
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
plt.figure(figsize=(12, 9))
sns.heatmap(df[num_cols].corr(), annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix — All Numeric Features\n(Look for features highly correlated with Production)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 3. 📐 Handling Zeros & Log-Transform
#
# ### The zero-production challenge
# Over 60% of rows have `Production = 0`. This happens when a district simply didn't grow that crop that year. These are **valid data points** — they shouldn't be removed. However, they do affect the distribution heavily.
#
# ### Why log-transform?
# `Production` is extremely right-skewed (skewness ≈ 4.3) — a few districts produce thousands of tonnes while most produce very little. Without transformation:
# - Linear models try to fit massive outliers and ignore small values
# - Error metrics are dominated by large-production districts
# - Tree splits get biased towards outlier thresholds
#
# We use `log1p(x) = log(x + 1)` which safely handles zeros (`log(0+1) = 0`) and compresses the range dramatically.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(df['Production'], bins=60, color='tomato', edgecolor='white')
axes[0].set_title(f'Production — Original\nSkewness: {df["Production"].skew():.2f}')
axes[0].set_xlabel('Production (thousand tonnes)')

log_prod = np.log1p(df['Production'])
axes[1].hist(log_prod, bins=60, color='steelblue', edgecolor='white')
axes[1].set_title(f'Production — After log1p\nSkewness: {log_prod.skew():.2f}')
axes[1].set_xlabel('log1p(Production)')

plt.suptitle('log1p transforms extreme skew into a workable distribution', fontsize=12)
plt.tight_layout()
plt.show()

print(f'Production skewness BEFORE: {df["Production"].skew():.2f}')
print(f'Production skewness AFTER : {log_prod.skew():.2f}')

# %% [markdown]
# ---
# ## 4. Feature Engineering & Preprocessing
#
# ### What we keep and what we drop
# - **Drop:** `Country` (always 'India' — zero information), `Ind_adm2_ID` (geographic admin ID, redundant with Latitude/Longitude)
# - **Keep:** `State_Encoded`, `District_Encoded`, `Crop_Encoded` — these are already label-encoded versions of the text columns, so we use them instead of the raw text columns to avoid needing one-hot encoding (which would create 475+ dummy columns for District alone)
# - **Drop:** `State`, `District`, `Crop` raw text columns (replaced by their encoded versions)
# - **Year:** Convert `'2021-22'` → `2021` (extract just the start year as a numeric feature)
#
# ### Train-Test Split (75/25)
# We split before any scaling. The model learns from the 75% training set; the 25% test set is only used at evaluation time — it simulates unseen real-world data.
#
# ### StandardScaler (no leakage)
# StandardScaler subtracts mean and divides by standard deviation. It's critical for SVR.
# - **Fit only on training data** → learn mean/std from training set
# - **Transform both train and test** using those same training statistics
#
# Fitting on test data would be leakage — the model would indirectly see future data during training, making evaluation metrics artificially optimistic.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# --- Feature Engineering ---
data = df.copy()

# Extract numeric year from '2021-22' → 2021
data['Year_Num'] = data['Year'].str[:4].astype(int)

# Drop non-predictive or redundant columns
data = data.drop(columns=['Country', 'Ind_adm2_ID', 'Year',
                           'State', 'District', 'Crop'])  # use encoded versions

print('Features used for modelling:')
for col in data.drop(columns=['Production']).columns:
    print(f'  {col}')

# --- Target ---
X = data.drop(columns=['Production'])
y = np.log1p(data['Production'])  # log-transform target

# --- Split ---
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# --- Scale (fit on train only) ---
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)   # learn mean/std from train
X_test_scaled  = scaler.transform(X_test)         # apply same params to test

print(f'\nX_train: {X_train.shape}  |  X_test: {X_test.shape}')
print('✅ Scaler fitted on training data only — no leakage.')

# %% [markdown]
# ---
# ## 5. Evaluation Helper
#
# We define a helper function that computes four metrics for any model's predictions and stores the results for the final comparison table.
#
# | Metric | Meaning | Better when |
# |--------|---------|-------------|
# | **R²** | % of variance in Production explained by the model | Higher (max 1.0) |
# | **Adj. R²** | R² penalised for number of features — more honest | Higher |
# | **RMSE** | Root mean squared error — penalises large errors heavily | Lower |
# | **MAE** | Mean absolute error — treats all errors equally | Lower |
#
# > Since Production is in log scale, RMSE = 0.5 means predictions are off by ≈ e^0.5 = 1.65x in original units.

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

results = []  # accumulates all model results for Section 11

def evaluate(name, y_true, y_pred, store=True):
    n, p = len(y_true), X_test.shape[1]
    r2   = r2_score(y_true, y_pred)
    adj  = 1 - (1 - r2) * (n - 1) / (n - p - 1)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae  = mean_absolute_error(y_true, y_pred)
    print(f"\n{'='*48}")
    print(f"  {name}")
    print(f"  R²        : {r2:.4f}")
    print(f"  Adj. R²   : {adj:.4f}")
    print(f"  RMSE      : {rmse:.4f}")
    print(f"  MAE       : {mae:.4f}")
    if store:
        results.append({'Model': name, 'R²': r2, 'Adj R²': adj, 'RMSE': rmse, 'MAE': mae})
    return r2

# %% [markdown]
# ---
# ## 6. Baseline Models
#
# We train four models with **default settings** first. These serve as our benchmark — any tuning or advanced model should improve upon these numbers.
#
# - **Linear Regression** — assumes a linear relationship. Fast, but our data has complex non-linear interactions (a crop's production depends jointly on soil, weather, location, etc.).
# - **Decision Tree** — learns if-else rules. Naturally handles non-linearity, but default settings often overfit (the tree grows until every leaf has just one sample).
# - **Random Forest** — builds many trees independently and averages them. Overfitting is much reduced compared to a single tree.
# - **SVR** — finds the best-fit hyperplane with a tolerance margin. Requires scaled features (done above). The `rbf` kernel handles non-linear patterns.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# Linear Regression
lr = LinearRegression()
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)
evaluate('Linear Regression', y_test, lr_pred)

# Decision Tree (default = unlimited depth → likely to overfit)
dt_base = DecisionTreeRegressor(random_state=42)
dt_base.fit(X_train, y_train)
dt_pred = dt_base.predict(X_test)
evaluate('Decision Tree (Baseline)', y_test, dt_pred)

# Random Forest (default 100 trees)
rf_base = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_base.fit(X_train, y_train)
rf_pred = rf_base.predict(X_test)
evaluate('Random Forest (Baseline)', y_test, rf_pred)

# SVR — uses scaled data (fitted on train only, no leakage)
svr = SVR(kernel='rbf')
svr.fit(X_train_scaled, y_train)
svr_pred = svr.predict(X_test_scaled)
evaluate('SVR (Fixed — no leakage)', y_test, svr_pred)

# %% [markdown]
# ---
# ## 7. 🔧 Hyperparameter Tuning
#
# ### Why tune?
# Default hyperparameters are generic starting points — they're rarely optimal for your specific dataset. Tuning can meaningfully improve R² and reduce errors.
#
# ### GridSearchCV vs RandomizedSearchCV
# - **GridSearchCV** tries every combination — good when the search space is small (Decision Tree)
# - **RandomizedSearchCV** randomly samples `n_iter` combinations — good when the space is large (Random Forest with 6 parameters)
#
# Both use **5-fold cross-validation**: training data is split into 5 parts. The model trains on 4 parts and validates on 1, rotating through all 5. The average score is used to pick the best hyperparameters. This is more reliable than a single validation split.
#
# ### Key parameters for this dataset:
# - `max_depth` — with 475 districts and 19 crops, deep trees can memorise patterns that don't generalise
# - `min_samples_leaf` — requiring a minimum number of samples per leaf prevents overfitting on rare district-crop combos
# - `n_estimators` — more trees = more stable Random Forest (at the cost of speed)

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from scipy.stats import randint

# --- Decision Tree: GridSearchCV ---
# Search space is manageable (5×3×3×3 = 135 combinations)
dt_grid = GridSearchCV(
    DecisionTreeRegressor(random_state=42),
    param_grid={
        'max_depth': [None, 5, 10, 15, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['sqrt', 'log2', None]
    },
    cv=5, scoring='r2', n_jobs=-1, verbose=0
)
dt_grid.fit(X_train, y_train)
best_dt = dt_grid.best_estimator_
dt_tuned_pred = best_dt.predict(X_test)

print('Best Decision Tree params:', dt_grid.best_params_)
print('Best CV R²:', round(dt_grid.best_score_, 4))
evaluate('Decision Tree (Tuned)', y_test, dt_tuned_pred)

# %%
# --- Random Forest: RandomizedSearchCV ---
# Large search space → random sampling of 30 combinations is much faster
rf_random = RandomizedSearchCV(
    RandomForestRegressor(random_state=42, n_jobs=-1),
    param_distributions={
        'n_estimators': randint(100, 400),
        'max_depth': [None, 5, 10, 15, 20, 30],
        'min_samples_split': randint(2, 15),
        'min_samples_leaf': randint(1, 8),
        'max_features': ['sqrt', 'log2', None],
        'bootstrap': [True, False]
    },
    n_iter=30, cv=5, scoring='r2', n_jobs=-1, random_state=42, verbose=0
)
rf_random.fit(X_train, y_train)
best_rf = rf_random.best_estimator_
rf_tuned_pred = best_rf.predict(X_test)

print('Best Random Forest params:', rf_random.best_params_)
print('Best CV R²:', round(rf_random.best_score_, 4))
evaluate('Random Forest (Tuned)', y_test, rf_tuned_pred)

# %% [markdown]
# ---
# ## 8. ⚡ XGBoost & LightGBM — Gradient Boosting
#
# ### What is Gradient Boosting?
# Unlike Random Forest (which builds trees independently and averages), gradient boosting builds trees **sequentially** — each new tree focuses on correcting the errors of all previous trees. This leads to higher accuracy but is more sensitive to hyperparameters.
#
# ### XGBoost vs LightGBM for this dataset
# - **XGBoost** grows trees level-by-level (breadth-first). Solid and reliable.
# - **LightGBM** grows leaf-by-leaf (depth-first on the highest-gain leaf). Faster on large datasets like this one (27K rows) and often achieves slightly better scores with the right `num_leaves`.
#
# ### Important hyperparameters here:
# - `learning_rate` — lower = more conservative, needs more trees. On a dataset with complex soil+weather+geography interactions, a lower learning rate often generalises better.
# - `subsample` / `colsample_bytree` — using only a fraction of rows/features per tree adds randomness and prevents overfitting
# - `reg_alpha` / `reg_lambda` — L1/L2 regularisation to penalise overly complex models

# %%
import xgboost as xgb

xgb_search = RandomizedSearchCV(
    xgb.XGBRegressor(random_state=42, verbosity=0, n_jobs=-1),
    param_distributions={
        'n_estimators': randint(100, 500),
        'max_depth': randint(3, 10),
        'learning_rate': [0.01, 0.05, 0.1, 0.2],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'reg_alpha': [0, 0.1, 0.5],
        'reg_lambda': [1, 1.5, 2]
    },
    n_iter=30, cv=5, scoring='r2', n_jobs=-1, random_state=42
)
xgb_search.fit(X_train, y_train)
best_xgb = xgb_search.best_estimator_
xgb_pred = best_xgb.predict(X_test)

print('Best XGBoost params:', xgb_search.best_params_)
evaluate('XGBoost (Tuned)', y_test, xgb_pred)

# %%
import lightgbm as lgb

lgb_search = RandomizedSearchCV(
    lgb.LGBMRegressor(random_state=42, verbosity=-1, n_jobs=-1),
    param_distributions={
        'n_estimators': randint(100, 500),
        'max_depth': randint(3, 10),
        'learning_rate': [0.01, 0.05, 0.1, 0.2],
        'num_leaves': randint(20, 100),
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'reg_alpha': [0, 0.1, 0.5],
        'reg_lambda': [1, 1.5, 2]
    },
    n_iter=30, cv=5, scoring='r2', n_jobs=-1, random_state=42
)
lgb_search.fit(X_train, y_train)
best_lgb = lgb_search.best_estimator_
lgb_pred = best_lgb.predict(X_test)

print('Best LightGBM params:', lgb_search.best_params_)
evaluate('LightGBM (Tuned)', y_test, lgb_pred)

# %% [markdown]
# ---
# ## 9. 📈 Learning Curves
#
# ### What learning curves reveal
# We plot training R² and validation R² as more training data is added (10% → 100%).
#
# | Pattern | What it means | How to fix |
# |---------|--------------|------------|
# | Training R² >> Validation R², large gap | **Overfitting** | More data, regularisation, simpler model |
# | Both scores low, converge quickly | **Underfitting** | More complex model, better features |
# | Both high, small gap | **Good fit** ✅ | Nothing to do |
# | Validation R² still rising at end | **Need more data** | Collect more samples |
#
# With 27K rows, we expect the curves to converge relatively early for tree models. The shaded band = ±1 standard deviation across 5 CV folds — narrow band = stable model.

# %%
from sklearn.model_selection import learning_curve

def plot_learning_curve(estimator, title, X, y, ax, color='steelblue'):
    train_sizes, train_scores, val_scores = learning_curve(
        estimator, X, y,
        train_sizes=np.linspace(0.1, 1.0, 10),
        cv=5, scoring='r2', n_jobs=-1
    )
    tm, ts = train_scores.mean(axis=1), train_scores.std(axis=1)
    vm, vs = val_scores.mean(axis=1),   val_scores.std(axis=1)

    ax.plot(train_sizes, tm, 'o-', color=color,  label='Training R²')
    ax.fill_between(train_sizes, tm-ts, tm+ts, alpha=0.15, color=color)
    ax.plot(train_sizes, vm, 's--', color='tomato', label='Validation R²')
    ax.fill_between(train_sizes, vm-vs, vm+vs, alpha=0.15, color='tomato')
    ax.set_title(title)
    ax.set_xlabel('Training Samples')
    ax.set_ylabel('R² Score')
    ax.legend(loc='lower right', fontsize=8)
    ax.set_ylim(-0.05, 1.05)
    ax.grid(True, alpha=0.3)

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
plot_learning_curve(best_dt,  'Decision Tree (Tuned)',  X_train, y_train, axes[0,0], '#f0ad4e')
plot_learning_curve(best_rf,  'Random Forest (Tuned)',  X_train, y_train, axes[0,1], 'steelblue')
plot_learning_curve(best_xgb, 'XGBoost (Tuned)',        X_train, y_train, axes[1,0], '#5cb85c')
plot_learning_curve(best_lgb, 'LightGBM (Tuned)',       X_train, y_train, axes[1,1], '#9b59b6')

plt.suptitle('Learning Curves\nBlue = Training R²  |  Red = Validation R²  |  Shaded = ±1 std', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 10. 📉 Residual Analysis
#
# ### What are residuals?
# `Residual = Actual − Predicted`. If the model predicted `log(production) = 3.5` but actual was `4.0`, residual = `+0.5` (under-predicted).
#
# ### Scatter plot (Residuals vs Predicted)
# - ✅ **Good:** random scatter around 0, no pattern
# - ❌ **Funnel (wider at high predictions):** model struggles with high-production districts
# - ❌ **Curve:** a non-linear relationship the model is missing
#
# ### Residual histogram
# - ✅ **Good:** bell-shaped, centered at 0
# - ❌ **Left/right skewed:** systematic over- or under-prediction
#
# For this dataset, pay attention to residuals near `log(production) = 0` — those are the many zero-production cases, and models sometimes cluster predictions there.

# %%
def plot_residuals(ax_sc, ax_hist, y_true, y_pred, title, color):
    res = np.array(y_true) - np.array(y_pred)
    ax_sc.scatter(y_pred, res, alpha=0.3, s=8, color=color)
    ax_sc.axhline(0, color='black', lw=1, linestyle='--')
    ax_sc.set_xlabel('Predicted log(Production)')
    ax_sc.set_ylabel('Residual')
    ax_sc.set_title(f'{title}\nResiduals vs Predicted')
    ax_sc.grid(True, alpha=0.3)

    ax_hist.hist(res, bins=50, color=color, edgecolor='white', alpha=0.85)
    ax_hist.axvline(0, color='black', lw=1, linestyle='--')
    ax_hist.set_xlabel('Residual')
    ax_hist.set_title(f'{title}\nResidual Distribution')
    ax_hist.grid(True, alpha=0.3)

fig, axes = plt.subplots(4, 2, figsize=(14, 22))
for i, (pred, name, col) in enumerate([
    (dt_tuned_pred, 'Decision Tree (Tuned)', '#f0ad4e'),
    (rf_tuned_pred, 'Random Forest (Tuned)', 'steelblue'),
    (xgb_pred,      'XGBoost (Tuned)',        '#5cb85c'),
    (lgb_pred,      'LightGBM (Tuned)',        '#9b59b6'),
]):
    plot_residuals(axes[i,0], axes[i,1], y_test, pred, name, col)

plt.suptitle('Residual Analysis — Ideal: random scatter around 0, bell-shaped histogram', fontsize=13, y=1.005)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 11. 🤖 XAI — SHAP (SHapley Additive exPlanations)
#
# ### Why explainability matters for crop production
# A government agriculture department or a farmer doesn't just want a number — they need to know **why** production is predicted to be high or low. Is it the soil? The weather? The district?
#
# ### What SHAP does
# SHAP assigns each feature a **contribution value** for each prediction, based on Shapley values from game theory. Imagine each feature as a player contributing to the team's score (the prediction):
# - **Positive SHAP** → this feature pushed production higher than the average
# - **Negative SHAP** → this feature pulled production lower than the average
# - The sum of all SHAP values + baseline = final prediction
#
# We use **TreeExplainer** which is specifically optimised for tree models (XGBoost, Random Forest). It's exact and fast — much faster than the generic KernelExplainer.

# %%
import shap

# Use best gradient boosting model for SHAP explanations
# (change to best_lgb if LightGBM scored higher in your run)
shap_model = best_xgb

explainer = shap.TreeExplainer(shap_model)

# Use 500 samples for SHAP (representative of full test set, manageable runtime)
X_shap = X_test.iloc[:500].reset_index(drop=True)
shap_values = explainer.shap_values(X_shap)

print(f'SHAP values computed for {X_shap.shape[0]} samples × {X_shap.shape[1]} features')
print(f'Baseline (average prediction): {explainer.expected_value:.4f}')

# %% [markdown]
# ### 11a. Global Feature Importance
# Mean |SHAP value| for each feature, averaged across all 500 samples. Shows which features matter most **overall**. For this crop dataset, we'd expect features like `Crop_Encoded` (what crop), `District_Encoded` (where), and `Nitrogen`/`Rainfall` to rank high.

# %%
shap.summary_plot(shap_values, X_shap, plot_type='bar', show=False)
plt.title('SHAP Global Feature Importance\n(Mean |SHAP value| = average impact on prediction across all samples)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11b. Beeswarm Plot — Direction of Impact
# Each dot = one sample. X-axis = SHAP value (impact). Color = feature value (red = high, blue = low).
#
# **Reading example:** If `weather_precip_mm` has mostly red dots on the right side → high rainfall pushes production up, which makes agronomic sense for most food grains.

# %%
shap.summary_plot(shap_values, X_shap, show=False)
plt.title('SHAP Beeswarm\nRed = high feature value | Blue = low | Right = increases prediction | Left = decreases')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11c. Waterfall Plot — Single Prediction Explained
# Shows how a **specific prediction** was built step by step from the baseline. Each bar = one feature's contribution. The final value is the sum of baseline + all contributions.

# %%
# Find an interesting sample — one with high production for clearer explanation
high_idx = int(np.argmax(y_test.values[:500]))

shap_exp = shap.Explanation(
    values=shap_values[high_idx],
    base_values=explainer.expected_value,
    data=X_shap.iloc[high_idx],
    feature_names=X_shap.columns.tolist()
)
shap.plots.waterfall(shap_exp, show=False)
actual_val = np.expm1(y_test.values[high_idx])
plt.title(f'SHAP Waterfall — High Production Sample\nActual Production: {actual_val:.1f} thousand tonnes')
plt.tight_layout()
plt.show()

# %%
# Also explain a zero-production sample — very different explanation
zero_mask = y_test.values[:500] == 0
zero_idx = int(np.where(zero_mask)[0][0]) if zero_mask.any() else 0

shap_exp_zero = shap.Explanation(
    values=shap_values[zero_idx],
    base_values=explainer.expected_value,
    data=X_shap.iloc[zero_idx],
    feature_names=X_shap.columns.tolist()
)
shap.plots.waterfall(shap_exp_zero, show=False)
plt.title(f'SHAP Waterfall — Zero/Low Production Sample\nActual Production: {np.expm1(y_test.values[zero_idx]):.1f} thousand tonnes')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11d. SHAP Dependence Plot — Top Feature Interaction
# Shows how the most important feature's value relates to its SHAP impact. The color = a second feature that interacts most with the first. Reveals non-linear relationships and feature interactions.

# %%
mean_abs_shap = np.abs(shap_values).mean(axis=0)
top_feature = X_shap.columns[np.argmax(mean_abs_shap)]
second_feature = X_shap.columns[np.argsort(mean_abs_shap)[::-1][1]]
print(f'Top feature: {top_feature}  |  2nd feature (interaction color): {second_feature}')

shap.dependence_plot(top_feature, shap_values, X_shap, interaction_index=second_feature, show=False)
plt.title(f'SHAP Dependence: {top_feature}\nColor = {second_feature} (interaction effect)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 12. 🔍 XAI — LIME (Local Interpretable Model-Agnostic Explanations)
#
# ### How LIME works (differently from SHAP)
# 1. Take one prediction to explain (e.g., District X, Crop Y, Year Z → Production = 120 tonnes)
# 2. Randomly **perturb** the input features many times (e.g., change rainfall slightly, change nitrogen level)
# 3. Ask the black-box model to predict each perturbed version
# 4. Fit a **simple linear model** to those perturbed examples (weighted by closeness to original)
# 5. Report the linear model's coefficients — these are the local explanation
#
# LIME is **model-agnostic** — it doesn't need to look inside the model, just query it. This makes it applicable to any future model type.
#
# ### SHAP vs LIME
# | | SHAP | LIME |
# |---|---|---|
# | Theory | Game theory (exact) | Local linear approx. (approximate) |
# | Consistency | Always consistent | Can vary between runs |
# | Model-agnostic | No (TreeExplainer is tree-specific) | Yes |
# | Global explanation | Yes | No (local only) |
# | Best use | Tree models, global insight | Any model, individual cases |

# %%
import lime
import lime.lime_tabular

lime_explainer = lime.lime_tabular.LimeTabularExplainer(
    training_data=X_train.values,
    feature_names=X_train.columns.tolist(),
    mode='regression',
    random_state=42
)
print('LIME explainer ready.')

# %%
# Explain the high-production sample (same one used in SHAP waterfall)
lime_exp_high = lime_explainer.explain_instance(
    X_test.iloc[high_idx].values,
    best_xgb.predict,
    num_features=12
)

pred_val = best_xgb.predict(X_test.iloc[[high_idx]])[0]
actual_val = y_test.values[high_idx]

fig = lime_exp_high.as_pyplot_figure()
plt.title(f'LIME — High Production Sample\n'
          f'Predicted: {pred_val:.3f}  |  Actual: {actual_val:.3f} (log scale)\n'
          f'Green = pushed prediction up  |  Red = pushed prediction down')
plt.tight_layout()
plt.show()

# %%
# Explain the zero-production sample — compare with the high-production explanation
# Notice how completely different features dominate
lime_exp_zero = lime_explainer.explain_instance(
    X_test.iloc[zero_idx].values,
    best_xgb.predict,
    num_features=12
)

pred_zero = best_xgb.predict(X_test.iloc[[zero_idx]])[0]
actual_zero = y_test.values[zero_idx]

fig2 = lime_exp_zero.as_pyplot_figure()
plt.title(f'LIME — Zero/Low Production Sample\n'
          f'Predicted: {pred_zero:.3f}  |  Actual: {actual_zero:.3f} (log scale)\n'
          f'Compare with previous plot — different features drive this prediction')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 13. 📊 Final Comparison Table — All Models, All Metrics
#
# ### How to pick the best model
# - **R² and Adj. R²** — higher is better. Primary indicator of model quality.
# - **RMSE** — lower is better. Penalises large errors more than small ones (squares first). Important if predicting high-production districts accurately is critical.
# - **MAE** — lower is better. Treats all errors equally. More robust to outliers.
# - If **RMSE >> MAE** → a few predictions are wildly wrong (outlier errors)
# - If **RMSE ≈ MAE** → errors are consistent in size across all samples
#
# With 63% zero-production rows, achieving high R² is challenging — zeros create a bimodal target distribution that's hard for any model to fit perfectly.

# %%
results_df = pd.DataFrame(results)
results_df = results_df.sort_values('R²', ascending=False).reset_index(drop=True)
results_df.index += 1

print('\n' + '='*72)
print('             FINAL MODEL COMPARISON — ALL METRICS')
print('='*72)
print(results_df.round(4).to_string())
print('='*72)
best_r2_model = results_df.iloc[0]
print(f'\n🏆 Best R²   : {best_r2_model["Model"]} ({best_r2_model["R²"]:.4f})')
print(f'   Best RMSE : {results_df.loc[results_df["RMSE"].idxmin(), "Model"]}')
print(f'   Best MAE  : {results_df.loc[results_df["MAE"].idxmin(), "Model"]}')

# %%
# Visual bar charts for all three metrics
fig, axes = plt.subplots(1, 3, figsize=(17, 6))
palette = plt.cm.RdYlGn(np.linspace(0.25, 0.9, len(results_df)))

for ax, metric in zip(axes, ['R²', 'RMSE', 'MAE']):
    vals = results_df[metric]
    bar_colors = palette if metric == 'R²' else palette[::-1]
    bars = ax.barh(results_df['Model'], vals, color=bar_colors)
    ax.set_title(f'{metric}  —  {"higher" if metric == "R²" else "lower"} is better')
    ax.set_xlabel(metric)
    for bar, v in zip(bars, vals):
        ax.text(bar.get_width() + max(vals)*0.01,
                bar.get_y() + bar.get_height()/2,
                f'{v:.4f}', va='center', fontsize=8)
    ax.invert_yaxis()
    ax.grid(True, axis='x', alpha=0.3)

plt.suptitle('Final Model Comparison — India Districts Crop Production Dataset\n'
             'Models ranked by R² (best at top)', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Top 5 features from SHAP
print('Top 5 Most Important Features (SHAP — XGBoost):')
print('These features have the largest average impact on Production predictions.\n')
top5_idx = np.argsort(mean_abs_shap)[::-1][:5]
for rank, i in enumerate(top5_idx, 1):
    print(f'  {rank}. {X_shap.columns[i]:<30}  mean |SHAP| = {mean_abs_shap[i]:.4f}')

print('\n' + '='*62)
print('  PIPELINE COMPLETE ✅')
print('='*62)
steps = [
    'Data loaded & explored',
    'Zero-production analysis done',
    'log1p transform applied to Production',
    'Data leakage prevented (scaler on train only)',
    'Year extracted as numeric feature',
    'Baseline models trained (LR, DT, RF, SVR)',
    'Hyperparameter tuning (GridSearch + Randomized)',
    'XGBoost + LightGBM trained & tuned',
    'Learning curves plotted',
    'Residual analysis done',
    'SHAP explanations (global + local + dependence)',
    'LIME explanations (high + zero production)',
    'Final comparison table with R², Adj R², RMSE, MAE',
]
for s in steps:
    print(f'  ✅  {s}')

# %% [markdown]
# ---
# ## 14. 💾 Save Best Model for Deployment
#
# ### What we save and why
# To make predictions on new data later, we save the model plus the supporting deployment files:
#
# | File | What it contains | Why it's needed |
# |------|-----------------|----------------|
# | `best_model.pkl` | The trained model (XGBoost/LightGBM/RF) | Makes the actual predictions |
# | `scaler.pkl` | The fitted StandardScaler | Needed only if the selected model was trained on scaled inputs |
# | `category_mappings.pkl` | State/District/Crop name-to-ID maps | Lets the app convert user-friendly names into encoded model inputs |
# | `model_metadata.pkl` | Feature names, column order, model name, metrics | Ensures new data has the right columns in the right order |
#
# ### Why joblib instead of pickle?
# `joblib` is the standard for saving sklearn/XGBoost objects. It handles large numpy arrays more efficiently than standard `pickle`, and is the format recommended by scikit-learn's own documentation.
#
# ### Important: save preprocessing context together with the model
# The app needs the exact feature order, category mappings, and scaler flag used during training. Without those files, predictions can silently use the wrong inputs.

# %%
import joblib
import os

# --- Identify the best model based on R² ---
best_row = results_df.iloc[0]  # already sorted by R² descending
best_name = best_row['Model']

# Map model name → actual trained estimator object
model_map = {
    'Linear Regression':          lr,
    'Decision Tree (Baseline)':   dt_base,
    'Decision Tree (Tuned)':      best_dt,
    'Random Forest (Baseline)':   rf_base,
    'Random Forest (Tuned)':      best_rf,
    'SVR (Fixed — no leakage)':   svr,
    'XGBoost (Tuned)':            best_xgb,
    'LightGBM (Tuned)':           best_lgb,
}

best_model_obj = model_map[best_name]

print(f'Best model  : {best_name}')
print(f'R²          : {best_row["R²"]:.4f}')
print(f'Adj. R²     : {best_row["Adj R²"]:.4f}')
print(f'RMSE        : {best_row["RMSE"]:.4f}')
print(f'MAE         : {best_row["MAE"]:.4f}')

# %%
# --- Save model, scaler, and metadata ---
os.makedirs('saved_model', exist_ok=True)

# 1. Save the best model
joblib.dump(best_model_obj, 'saved_model/best_model.pkl')
print('✅ Saved: saved_model/best_model.pkl')

# 2. Save the scaler (MUST be saved — needed to scale new inputs before prediction)
joblib.dump(scaler, 'saved_model/scaler.pkl')
print('✅ Saved: saved_model/scaler.pkl')

# 3. Save category mappings for app inputs that start from names instead of encoded IDs
category_mappings = {
    'State': dict(sorted(df[['State', 'State_Encoded']].drop_duplicates().values.tolist())),
    'District': dict(sorted(df[['District', 'District_Encoded']].drop_duplicates().values.tolist())),
    'Crop': dict(sorted(df[['Crop', 'Crop_Encoded']].drop_duplicates().values.tolist())),
}
joblib.dump(category_mappings, 'saved_model/category_mappings.pkl')
print('✅ Saved: saved_model/category_mappings.pkl')

# 4. Save metadata — feature names, order, model info, and performance metrics
metadata = {
    'model_name':    best_name,
    'feature_names': X_train.columns.tolist(),
    'n_features':    X_train.shape[1],
    'target':        'log1p(Production)',
    'model_class':   type(best_model_obj).__name__,
    'requires_scaling': best_name.startswith('SVR'),
    'note':          'Predictions are in log1p scale — apply np.expm1() to get thousand tonnes',
    'metrics': {
        'R2':     round(best_row['R²'], 4),
        'Adj_R2': round(best_row['Adj R²'], 4),
        'RMSE':   round(best_row['RMSE'], 4),
        'MAE':    round(best_row['MAE'], 4),
    }
}
joblib.dump(metadata, 'saved_model/model_metadata.pkl')
print('✅ Saved: saved_model/model_metadata.pkl')

print(f'\n📁 All files saved in: saved_model/')
print('   ├── best_model.pkl')
print('   ├── scaler.pkl')
print('   ├── category_mappings.pkl')
print('   └── model_metadata.pkl')

# %% [markdown]
# ### How to load and use the saved model for predictions
#
# The cell below shows exactly how to load the saved model and predict on new data. You can copy this into any new script or notebook.

# %%
# ============================================================
# HOW TO USE THE SAVED MODEL FOR NEW PREDICTIONS
# Copy this block into any future script or notebook
# ============================================================

import joblib
import numpy as np
import pandas as pd

# --- Step 1: Load saved files ---
model    = joblib.load('saved_model/best_model.pkl')
scaler   = joblib.load('saved_model/scaler.pkl')
metadata = joblib.load('saved_model/model_metadata.pkl')

print(f"Loaded model   : {metadata['model_name']}")
print(f"Features needed: {metadata['feature_names']}")
print(f"Model R²       : {metadata['metrics']['R2']}")
print(f"Note           : {metadata['note']}")

# --- Step 2: Prepare new input data ---
# Create a DataFrame with the SAME columns in the SAME order as training
# Replace these values with your actual new data
new_data = pd.DataFrame([{
    'State_Encoded':          5,       # encoded state ID
    'District_Encoded':       42,      # encoded district ID
    'Crop_Encoded':           11,      # encoded crop ID (e.g., 11 = Rice)
    'Latitude':               20.5,    # district latitude
    'Longitude':              78.2,    # district longitude
    'Nitrogen (kg/ha)':       180.0,   # soil nitrogen
    'Phosphorus (kg/ha)':     20.0,    # soil phosphorus
    'Potassium (kg/ha)':      200.0,   # soil potassium
    'Organic Carbon (%)':     0.6,     # soil organic carbon
    'Soil pH':                6.8,     # soil pH
    'weather_temp_c':         27.5,    # average temperature (°C)
    'weather_humidity_pct':   75,      # humidity (%)
    'weather_precip_mm':      0.3,     # precipitation (mm)
    'weather_sunshine_hours': 8.5,     # sunshine hours
    'Year_Num':               2024,    # crop year
}])

# --- Step 3: Ensure column order matches training ---
new_data = new_data[metadata['feature_names']]

# --- Step 4: Scale only when the saved model was trained on scaled inputs ---
model_input = scaler.transform(new_data) if metadata.get('requires_scaling', False) else new_data

# --- Step 5: Predict ---
# Model outputs log1p(Production) — apply expm1 to get actual thousand tonnes
log_pred = model.predict(model_input)
production_pred = np.expm1(log_pred)

print(f'\n🌾 Predicted Production: {production_pred[0]:.2f} thousand tonnes')
print(f'   (log1p prediction was: {log_pred[0]:.4f})')

# %%
# --- Batch prediction example: predict for multiple rows at once ---

# Use actual test set rows as example batch (real values you already have)
sample_batch = X_test.iloc[:5].copy()

log_preds = model.predict(sample_batch)
actual_preds = np.expm1(log_preds)
actual_true  = np.expm1(y_test.values[:5])

comparison = pd.DataFrame({
    'Actual Production (k tonnes)':    actual_true.round(2),
    'Predicted Production (k tonnes)': actual_preds.round(2),
    'Error (k tonnes)':               (actual_preds - actual_true).round(2),
    'Error %':                        (np.abs(actual_preds - actual_true) / (actual_true + 1) * 100).round(1)
})

print('Batch Prediction Sample (5 rows from test set):\n')
print(comparison.to_string())

print('\n✅ Model is ready for deployment.')
print('   Load best_model.pkl + scaler.pkl + model_metadata.pkl')
print('   Follow the steps above to predict on any new district-crop-year combination.')
